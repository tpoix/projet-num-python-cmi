# %% [markdown]
# L'objectif de ce programme est de retrouver la structure associée d'une molécule à partr d'une masse mesurée par spectrométrie de masse.
# Ce qui est mesuré est en réalisé le rapport m/z : masse sur charge de la molécule. Il faut savoir que la charge d'une molécule est due à l'ajout de protons (H+).
#
# Plusieurs objectifs étaient prévus :
#
#     - Lire ou saisir les données concernant la masse des différents constituants de la molécule
#     - Calculer la masse théorique de la molécule et son rapport m/z
#     - Extraire la composition élémentaire de la molécule
#     - Construire une liste de candidats qui respecte les contraintes
#     - Comparer le rapport m/z mesuré expérimentalement aux valeurs d'une série de candidats potentiels.

# %% [markdown]
# Nous avons dû calculer le rapport m/z pour les molécules 1 à 21, pour cela nous avons réutilisé la formule présente dans le document Excel. Nous avons donc refait sur le document Excel :
#
#                                         (masse théorique x 2 (Masse Hydrogène))/2
#
# Nous avons récupéré les données complétées afin de les traiter sur Python.

# %%
import pandas as pd
molecules = pd.read_excel('Pyoverdine Germain Final.xlsx', header=1, sheet_name="Molécules")
molecules
# Out:
#     Molécule                ID      m/z 2+  Masse théo  NbrC  NbrH  NbrO  \
# 0          1               Ser   44.523839   87.032029   3.0   5.0   2.0
# 1          2               Val   50.542032   99.068414   5.0   9.0   1.0
# 2          3               Lys   65.055307  128.094963   6.0  12.0   1.0
# 3          4               Ala   36.526382   71.037114   3.0   5.0   1.0
# 4          5               Gly   29.518557   57.021464   2.0   3.0   1.0
# 5          6               Glu   65.529122  129.042594   5.0   7.0   3.0
# 6          7               Thr   51.531664  101.047679   4.0   7.0   2.0
# 7          8               Asp   58.521297  115.026944   4.0   5.0   3.0
# 8          9               Arg   79.058380  156.101111   6.0  12.0   1.0
# 9         10               Gln   65.037114  128.058578   5.0   8.0   2.0
# 10        11               Orn   58.047481  114.079313   5.0  10.0   1.0
# 11        12             e-Lys   65.055307  128.094963   6.0  12.0   1.0
# 12        13           AOH-Orn   87.050221  172.084793   7.0  12.0   3.0
# 13        14           FOH-Orn   80.042396  158.069143   6.0  10.0   3.0
# 14        15           cOH-Orn   65.541027  129.066403   5.0   9.0   2.0
# 15        16             OHHis   77.534739  153.053827   6.0   7.0   2.0
# 16        17             OHAsp   66.518755  131.021859   4.0   5.0   4.0
# 17        18               Dab   51.039656  100.063663   4.0   8.0   1.0
# 18        19               Asn   58.029289  114.042928   4.0   6.0   2.0
# 19        20  Cyclisation -H2O   10.013108   18.010565   NaN   2.0   1.0
# 20        21       OH Terminal    9.509195   17.002740   NaN   1.0   1.0
# 21        31           Chr1et2  129.547846  257.080042  13.0  11.0   3.0
# 22        32              Chr3  143.041391  284.067132  14.0  10.0   4.0
# 23        33              Chr4  171.054499  340.093347  17.0  14.0   5.0
# 24        34              Chr5  130.555671  259.095692  13.0  13.0   3.0
# 25        35              Chr6  170.534079  339.052508  13.0  13.0   6.0
# 26        36              Chr7  123.566039  245.116427  13.0  15.0   2.0
# 27        37               Suc   51.519760  101.023870   4.0   5.0   3.0
# 28        38              Suca   51.027752  100.039854   4.0   6.0   2.0
# 29        39               Mal   59.517218  117.018785   4.0   5.0   4.0
# 30        40              Mala   59.025210  116.034769   4.0   6.0   3.0
# 31        41        Glu(-chro)   66.033034  130.050419   5.0   8.0   3.0
# 32        42               Kgl   65.517218  129.018785   5.0   5.0   4.0
# 33        44                Fe   28.975020   55.934390   NaN   NaN   NaN
# 34        46                Al   14.498596   26.981541   NaN   NaN   NaN
# 35        47           Fe - 3H   27.463283   52.910915   NaN   3.0   NaN
# 36        48           Al - 3H   12.986858   23.958066   NaN   3.0   NaN
#
#     NbrN  NbrSe  NbrP  NbrS  NbrNa  NbrK  NbrFe  NbrAl  e-
# 0    1.0    NaN   NaN   NaN    NaN   NaN    NaN    NaN NaN
# 1    1.0    NaN   NaN   NaN    NaN   NaN    NaN    NaN NaN
# 2    2.0    NaN   NaN   NaN    NaN   NaN    NaN    NaN NaN
# 3    1.0    NaN   NaN   NaN    NaN   NaN    NaN    NaN NaN
# 4    1.0    NaN   NaN   NaN    NaN   NaN    NaN    NaN NaN
# 5    1.0    NaN   NaN   NaN    NaN   NaN    NaN    NaN NaN
# 6    1.0    NaN   NaN   NaN    NaN   NaN    NaN    NaN NaN
# 7    1.0    NaN   NaN   NaN    NaN   NaN    NaN    NaN NaN
# 8    4.0    NaN   NaN   NaN    NaN   NaN    NaN    NaN NaN
# 9    2.0    NaN   NaN   NaN    NaN   NaN    NaN    NaN NaN
# 10   2.0    NaN   NaN   NaN    NaN   NaN    NaN    NaN NaN
# 11   2.0    NaN   NaN   NaN    NaN   NaN    NaN    NaN NaN
# 12   2.0    NaN   NaN   NaN    NaN   NaN    NaN    NaN NaN
# 13   2.0    NaN   NaN   NaN    NaN   NaN    NaN    NaN NaN
# 14   2.0    NaN   NaN   NaN    NaN   NaN    NaN    NaN NaN
# 15   3.0    NaN   NaN   NaN    NaN   NaN    NaN    NaN NaN
# 16   1.0    NaN   NaN   NaN    NaN   NaN    NaN    NaN NaN
# 17   2.0    NaN   NaN   NaN    NaN   NaN    NaN    NaN NaN
# 18   2.0    NaN   NaN   NaN    NaN   NaN    NaN    NaN NaN
# 19   NaN    NaN   NaN   NaN    NaN   NaN    NaN    NaN NaN
# 20   NaN    NaN   NaN   NaN    NaN   NaN    NaN    NaN NaN
# 21   3.0    NaN   NaN   NaN    NaN   NaN    NaN    NaN NaN
# 22   3.0    NaN   NaN   NaN    NaN   NaN    NaN    NaN NaN
# 23   3.0    NaN   NaN   NaN    NaN   NaN    NaN    NaN NaN
# 24   3.0    NaN   NaN   NaN    NaN   NaN    NaN    NaN NaN
# 25   3.0    NaN   NaN   1.0    NaN   NaN    NaN    NaN NaN
# 26   3.0    NaN   NaN   NaN    NaN   NaN    NaN    NaN NaN
# 27   NaN    NaN   NaN   NaN    NaN   NaN    NaN    NaN NaN
# 28   1.0    NaN   NaN   NaN    NaN   NaN    NaN    NaN NaN
# 29   NaN    NaN   NaN   NaN    NaN   NaN    NaN    NaN NaN
# 30   1.0    NaN   NaN   NaN    NaN   NaN    NaN    NaN NaN
# 31   1.0    NaN   NaN   NaN    NaN   NaN    NaN    NaN NaN
# 32   NaN    NaN   NaN   NaN    NaN   NaN    NaN    NaN NaN
# 33   NaN    NaN   NaN   NaN    NaN   NaN    1.0    NaN NaN
# 34   NaN    NaN   NaN   NaN    NaN   NaN    NaN    1.0 NaN
# 35   NaN    NaN   NaN   NaN    NaN   NaN    1.0    NaN NaN
# 36   NaN    NaN   NaN   NaN    NaN   NaN    NaN    1.0 NaN

# %% [markdown]
# Nous avons ensuite commencé à travailler sur l'extraction des différentes possibilités pour une masse mesurée. Mais certaines conditions sont à remplir :
#
#     - Il faut forcément un chromophore mais un seul à chaque fois
#     - Il faut forcément une side chaine et une seule à chaque fois SAUF si on a Chr3 ou Chr4 (= ce sont des chromophores)
#     - ll faut que la teneur en azote soit égale à 14 dans la molécule finale
#     - Il faut donc forcément des acides aminés mais pas forcément des terminaisons ou des métaux
#     - Si cOH = 1 alors OH terminal = 0

# %% [markdown]
# Deux stratégies :
#
#     - tester toutes les possibilités (tester 1 à 10 chacun etc mais traitement automatique et voir ce qui marche)
#     - optimiser les coefficients et varier un truc et voir si on se rapproche ou s'éloigne de la valeur cible

# %% [markdown]
# Il faut assigner les masses théoriques à chaque élement.
#
# Le résultat qu'on obtiendra devra être divisé par deux, un ou rien en fonction du niveau de ionisation connu de la molécule. Dans les trois exemples donnés ici c'est 2.

# %% [markdown]
# Essais de plusieurs techniques sur de petites quantité d'atomes :

# %% [markdown]
#     - Méthode anti-vol
